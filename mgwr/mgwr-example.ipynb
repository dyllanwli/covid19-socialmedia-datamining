# %%
import numpy as np
from mgwr.gwr import GWR, MGWR
from mgwr.sel_bw import Sel_BW
from mgwr.utils import shift_colormap, truncate_colormap
import geopandas as gp
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
# --> 158             conn = connection.create_connection(
#     159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     596             # Make the request on the httplib connection object.
# --> 597             httplib_response = self._make_request(conn, method, url,
#     598                                                   timeout=timeout_obj,
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     166         except SocketError as e:
# --> 167             raise NewConnectionError(
#     168                 self, "Failed to establish a new connection: %s" % e)
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x2aea9f292b20>: Failed to establish a new connection: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     636
# --> 637             retries = retries.increment(method, url, error=e, _pool=self,
#     638                                         _stacktrace=sys.exc_info()[2])
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='geodacenter.github.io', port=443): Max retries exceeded with url: /data-and-lab// (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x2aea9f292b20>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-5a6ba1ee9b11> in <module>
#       1 import numpy as np
# ----> 2 from mgwr.gwr import GWR, MGWR
#       3 from mgwr.sel_bw import Sel_BW
#       4 from mgwr.utils import shift_colormap, truncate_colormap
#       5 import geopandas as gp
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/mgwr/__init__.py in <module>
#       1 __version__ = "2.1.1"
#       2
# ----> 3 from . import gwr
#       4 from . import sel_bw
#       5 from . import diagnostics
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/mgwr/gwr.py in <module>
#       9 from scipy.special import factorial
#      10 from itertools import combinations as combo
# ---> 11 from spglm.family import Gaussian, Binomial, Poisson
#      12 from spglm.glm import GLM, GLMResults
#      13 from spglm.iwls import iwls, _compute_betas_gwr
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/spglm/__init__.py in <module>
#       1 __version__ = '1.0.7'
#       2
# ----> 3 from . import glm
#       4 from . import family
#       5 from . import utils
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/spglm/glm.py in <module>
#       5 import numpy as np
#       6 import numpy.linalg as la
# ----> 7 from spreg.utils import RegressionPropsY, spdot
#       8 from spreg import user_output as USER
#       9 from .utils import cache_readonly
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/spreg/__init__.py in <module>
#       1 __version__ = "1.1.1"
# ----> 2 from .ols import *
#       3 from .diagnostics import *
#       4 from .diagnostics_sp import *
#       5 from .diagnostics_sur import *
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/spreg/ols.py in <module>
#       5 import copy as COPY
#       6 import numpy.linalg as la
# ----> 7 from . import user_output as USER
#       8 from . import summary_output as SUMMARY
#       9 from . import robust as ROBUST
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/spreg/user_output.py in <module>
#       9 from . import diagnostics
#      10 from . import sputils as spu
# ---> 11 from libpysal import weights
#      12 from scipy.sparse.csr import csr_matrix
#      13
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/libpysal/__init__.py in <module>
#      28 from . import io
#      29 from . import weights
# ---> 30 from . import examples
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/libpysal/examples/__init__.py in <module>
#       3 """
#       4 from .base import example_manager
# ----> 5 from .remotes import datasets as remote_datasets
#       6 from .remotes import download as fetch_all
#       7 from .builtin import datasets as builtin_datasets
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/libpysal/examples/remotes.py in <module>
#      12
#      13 url = "https://geodacenter.github.io/data-and-lab//"
# ---> 14 page = requests.get(url)
#      15 soup = BeautifulSoup(page.text, 'html.parser')
#      16 samples = soup.find(class_='samples')
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /scratch/user/diya.li/.conda/envs/jupyterlab_2.0.1/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='geodacenter.github.io', port=443): Max retries exceeded with url: /data-and-lab// (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x2aea9f292b20>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
